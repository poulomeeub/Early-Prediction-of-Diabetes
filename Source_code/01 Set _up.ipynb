# %% [markdown]
# # Installing libraries

# %%
# !pip install stats
# !pip install catboost
# !pip install lightgbm
# !pip install pandas-profiling
# !pip install --upgrade scikit-learn imbalanced-learn
# !pip install mlxtend
# !pip install imbalanced-learn
# !pip install tensorflow
# !pip install --upgrade scikit-learn
# Out:
# Collecting stats
#   Downloading stats-0.1.2a.tar.gz (127 kB)
#      ---------------------------------------- 0.0/127.6 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/127.6 kB ? eta -:--:--
#      -------- ---------------------------- 30.7/127.6 kB 262.6 kB/s eta 0:00:01
#      -------------------- ---------------- 71.7/127.6 kB 435.7 kB/s eta 0:00:01
#      ------------------------------------ 127.6/127.6 kB 682.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: stats
#   Building wheel for stats (setup.py): started
#   Building wheel for stats (setup.py): finished with status 'done'
#   Created wheel for stats: filename=stats-0.1.2a0-py3-none-any.whl size=24296 sha256=31e58250d9c667f7e2c1c81280d461bd04b43c6913af910425a1d13a0b033600
#   Stored in directory: c:\users\poulo\appdata\local\pip\cache\wheels\57\7d\91\f1d0158783f74ab6ad725b00aa6a2c6e976cea652eb72616c6
# Successfully built stats
# Installing collected packages: stats
# Successfully installed stats-0.1.2a0
# Requirement already satisfied: catboost in c:\users\poulo\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: graphviz in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (3.7.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (1.24.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (1.11.1)
# Requirement already satisfied: plotly in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (5.9.0)
# Requirement already satisfied: six in c:\users\poulo\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\poulo\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: lightgbm in c:\users\poulo\anaconda3\lib\site-packages (4.2.0)
# Requirement already satisfied: numpy in c:\users\poulo\anaconda3\lib\site-packages (from lightgbm) (1.24.3)
# Requirement already satisfied: scipy in c:\users\poulo\anaconda3\lib\site-packages (from lightgbm) (1.11.1)
# Requirement already satisfied: pandas-profiling in c:\users\poulo\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (1.11.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (2.0.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (3.7.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (1.10.8)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (1.24.3)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\poulo\anaconda3\lib\site-packages (from pandas-profiling) (1.10)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\poulo\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\poulo\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Requirement already satisfied: imagehash in c:\users\poulo\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\poulo\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\poulo\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\poulo\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\poulo\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\poulo\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\poulo\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\poulo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\poulo\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Requirement already satisfied: scikit-learn in c:\users\poulo\anaconda3\lib\site-packages (1.3.0)
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/a8/e9/3e4879974a7c4dcaca2a746dde3df08d0ae8f14c74b03591616ce5f0a8b1/scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata
#   Downloading scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: imbalanced-learn in c:\users\poulo\anaconda3\lib\site-packages (0.10.1)
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/92/e8/86c36e1b13007ca9c89381adac6c078cfc8fb71841a76c08a3fe3eca91d3/imbalanced_learn-0.12.0-py3-none-any.whl.metadata
#   Downloading imbalanced_learn-0.12.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Downloading scikit_learn-1.4.0-1-cp311-cp311-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 660.6 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/10.6 MB 4.9 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.5/10.6 MB 10.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.6 MB 18.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.6/10.6 MB 23.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.6 MB 27.2 MB/s eta 0:00:01
#    ------------------------------------ --- 9.8/10.6 MB 31.2 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 34.4 MB/s eta 0:00:00
# Downloading imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
#    ---------------------------------------- 0.0/257.7 kB ? eta -:--:--
#    ---------------------------------------- 257.7/257.7 kB ? eta 0:00:00
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------- 302.2/302.2 kB ? eta 0:00:00
# Installing collected packages: joblib, scikit-learn, imbalanced-learn
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# Successfully installed imbalanced-learn-0.12.0 joblib-1.3.2 scikit-learn-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.3.2 which is incompatible.
# Requirement already satisfied: mlxtend in c:\users\poulo\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\poulo\anaconda3\lib\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\poulo\anaconda3\lib\site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\poulo\anaconda3\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\poulo\anaconda3\lib\site-packages (from mlxtend) (1.4.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\poulo\anaconda3\lib\site-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\poulo\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\poulo\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\poulo\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Requirement already satisfied: imbalanced-learn in c:\users\poulo\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\poulo\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\poulo\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\poulo\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\poulo\anaconda3\lib\site-packages (from imbalanced-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: tensorflow in c:\users\poulo\anaconda3\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\poulo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\poulo\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\poulo\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\poulo\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\poulo\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\poulo\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\poulo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\poulo\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\poulo\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\poulo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\poulo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\poulo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\poulo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\poulo\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\poulo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Requirement already satisfied: scikit-learn in c:\users\poulo\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\poulo\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

## For statistical test
from scipy.stats import chisquare, chi2_contingency ## Stastical test
from scipy.stats import probplot
from scipy import stats
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

## machine learning libary
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix, precision_recall_fscore_support,roc_curve
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.datasets import make_classification
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

from sklearn.metrics import confusion_matrix,roc_curve, classification_report
from sklearn.metrics import mean_absolute_error , mean_absolute_percentage_error , mean_squared_error , accuracy_score
from mlxtend.plotting import plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
# %matplotlib inline
import tensorflow as tf
import warnings

from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

#from sklearn.metrics import confusion_matrix, plot_roc_curve, roc_auc_score
from imblearn.over_sampling import SMOTE

#Importing Visualization library

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import plotly.express as px
px_template = "pink"
